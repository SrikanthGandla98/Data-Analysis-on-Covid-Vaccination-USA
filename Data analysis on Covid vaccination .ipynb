# %%
import pandas as pd
import numpy as ns
import matplotlib.pyplot as plt

# %%
CovidV=pd.read_csv(r'C:\Users\SRIKANTH SHR\Desktop\Data analysis  in Excel\Covid vaccination\country_vaccinations.csv')

# %%
CovidV.head(10)
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
# 5  Argentina      ARG  2021-01-03                 NaN                NaN
# 6  Argentina      ARG  2021-01-04             39599.0                NaN
# 7  Argentina      ARG  2021-01-05                 NaN                NaN
# 8  Argentina      ARG  2021-01-06                 NaN                NaN
# 9  Argentina      ARG  2021-01-07                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
CovidV.shape
# Out:
# (1502, 15)

# %%
CovidV.isnull().sum()
# Out:
# country                                   0
# iso_code                                165
# date                                      0
# total_vaccinations                      485
# people_vaccinated                       537
# people_fully_vaccinated                1204
# daily_vaccinations_raw                  675
# daily_vaccinations                       60
# total_vaccinations_per_hundred          485
# people_vaccinated_per_hundred           537
# people_fully_vaccinated_per_hundred    1204
# daily_vaccinations_per_million           60
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
CovidVc=CovidV.dropna()

# %%
CovidVc.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
CovidVc.shape
# Out:
# (217, 15)

# %%
CovidVc.head(5)
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 23  Argentina      ARG  2021-01-21            265724.0           249372.0
# 24  Argentina      ARG  2021-01-22            279602.0           254456.0
# 25  Argentina      ARG  2021-01-23            288064.0           258876.0
# 26  Argentina      ARG  2021-01-24            292023.0           260036.0
# 27  Argentina      ARG  2021-01-25            292386.0           260122.0
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 23                  16352.0                 17791.0             11704.0
# 24                  25146.0                 13878.0             11263.0
# 25                  29188.0                  8462.0             11124.0
# 26                  31987.0                  3959.0             10342.0
# 27                  32264.0                   363.0              9046.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
CovidVc['country'].unique()
# Out:
# array(['Argentina', 'Belgium', 'Bulgaria', 'Chile', 'Denmark', 'Germany',
#        'Greece', 'Hungary', 'Israel', 'Italy', 'Lithuania', 'Mexico',
#        'Norway', 'Oman', 'Poland', 'Portugal', 'Romania', 'Slovakia',
#        'Slovenia', 'Spain', 'United Arab Emirates', 'United Kingdom',
#        'United States'], dtype=object)

# %%
CovidVacci=CovidVc.drop(['total_vaccinations_per_hundred','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred','daily_vaccinations_per_million'],axis=1)

# %%
CovidVacci.head()
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 23  Argentina      ARG  2021-01-21            265724.0           249372.0
# 24  Argentina      ARG  2021-01-22            279602.0           254456.0
# 25  Argentina      ARG  2021-01-23            288064.0           258876.0
# 26  Argentina      ARG  2021-01-24            292023.0           260036.0
# 27  Argentina      ARG  2021-01-25            292386.0           260122.0
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 23                  16352.0                 17791.0             11704.0
# 24                  25146.0                 13878.0             11263.0
# 25                  29188.0                  8462.0             11124.0
# 26                  31987.0                  3959.0             10342.0
# 27                  32264.0                   363.0              9046.0
#
#      vaccines         source_name  \
# 23  Sputnik V  Ministry of Health
# ...

# %%
CovidVacci.drop(['source_website'],axis=1)
# Out:
#             country iso_code        date  total_vaccinations  \
# 23        Argentina      ARG  2021-01-21            265724.0
# 24        Argentina      ARG  2021-01-22            279602.0
# 25        Argentina      ARG  2021-01-23            288064.0
# 26        Argentina      ARG  2021-01-24            292023.0
# 27        Argentina      ARG  2021-01-25            292386.0
# ...             ...      ...         ...                 ...
# 1454  United States      USA  2021-01-21          17546374.0
# 1455  United States      USA  2021-01-22          19107959.0
# 1456  United States      USA  2021-01-23          20537990.0
# 1457  United States      USA  2021-01-24          21848655.0
# 1458  United States      USA  2021-01-25          22734243.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 23             249372.0                  16352.0                 17791.0
# 24             254456.0                  25146.0                 13878.0
# ...

# %%
CovidVacci['date'].unique()
# Out:
# array(['2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24',
#        '2021-01-25', '2021-01-18', '2021-01-19', '2021-01-20',
#        '2021-01-14', '2021-01-15', '2021-01-16', '2021-01-17',
#        '2020-12-28', '2020-12-29', '2020-12-30', '2020-12-31',
#        '2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#        '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#        '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#        '2021-01-13'], dtype=object)

# %%
CovidVacci['date']=pd.to_datetime(CovidVacci['date'],utc=True)

# %%
CovidVacci['date']
# Out:
# 23     2021-01-21 00:00:00+00:00
# 24     2021-01-22 00:00:00+00:00
# 25     2021-01-23 00:00:00+00:00
# 26     2021-01-24 00:00:00+00:00
# 27     2021-01-25 00:00:00+00:00
#                   ...
# 1454   2021-01-21 00:00:00+00:00
# 1455   2021-01-22 00:00:00+00:00
# 1456   2021-01-23 00:00:00+00:00
# 1457   2021-01-24 00:00:00+00:00
# 1458   2021-01-25 00:00:00+00:00
# Name: date, Length: 217, dtype: datetime64[ns, UTC]

# %%
CovidVacci=CovidVacci.set_index('date')
CovidVacci.head()
# Out:
#                              country iso_code  total_vaccinations  \
# date
# 2021-01-21 00:00:00+00:00  Argentina      ARG            265724.0
# 2021-01-22 00:00:00+00:00  Argentina      ARG            279602.0
# 2021-01-23 00:00:00+00:00  Argentina      ARG            288064.0
# 2021-01-24 00:00:00+00:00  Argentina      ARG            292023.0
# 2021-01-25 00:00:00+00:00  Argentina      ARG            292386.0
#
#                            people_vaccinated  people_fully_vaccinated  \
# date
# 2021-01-21 00:00:00+00:00           249372.0                  16352.0
# 2021-01-22 00:00:00+00:00           254456.0                  25146.0
# 2021-01-23 00:00:00+00:00           258876.0                  29188.0
# 2021-01-24 00:00:00+00:00           260036.0                  31987.0
# 2021-01-25 00:00:00+00:00           260122.0                  32264.0
#
#                            daily_vaccinations_raw  daily_vaccinations  \
# date
# ...

# %%
CovidVaccination_mean=CovidVacci[['country','total_vaccinations','people_vaccinated','people_fully_vaccinated']].resample('M').mean()
CovidVaccination_mean.head()
# Out:
#                            total_vaccinations  people_vaccinated  \
# date
# 2020-12-31 00:00:00+00:00        1.145662e+05       1.145652e+05
# 2021-01-31 00:00:00+00:00        1.663106e+06       1.467790e+06
#
#                            people_fully_vaccinated
# date
# 2020-12-31 00:00:00+00:00                 1.000000
# 2021-01-31 00:00:00+00:00            191214.615023

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(15,8))
plt.title('Overall Anaylsis on Covid Vaccination')
sns.lineplot(data=CovidVaccination_mean)
